# %% [markdown]
# # Sample Notebook — Month 1
#
# This is a tiny starter notebook to confirm the repository works.

# %%
import sys
print('Hello — DataScience Masterplan')
print('Python version:', sys.version.split()[0])
